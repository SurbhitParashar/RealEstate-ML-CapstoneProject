# %%
import numpy as numpy
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('flats.csv')
df.sample(5)
# Out:
#                          property_name  \
# 86     3 BHK Flat in Sector 61 Gurgaon
# 2152               3 BHK Flat in Sohna
# 732   4 BHK Flat in Sector 82A Gurgaon
# 222    3 BHK Flat in Sector 65 Gurgaon
# 1718   3 BHK Flat in Sector 84 Gurgaon
#
#                                                    link  \
# 86    https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2152  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 732   https://www.99acres.com/4-bhk-bedroom-apartmen...
# 222   https://www.99acres.com/3-bhk-bedroom-apartmen...
# 1718  https://www.99acres.com/3-bhk-bedroom-apartmen...
#
#                          society       price             area  \
# 86            Puri The Aravallis  3.87 Crore  ₹ 17,200/sq.ft.
# 2152  Central Park Flower Valley   1.2 Crore   ₹ 6,742/sq.ft.
# 732          DLF The Primus3.9 ★  2.95 Crore  ₹ 11,451/sq.ft.
# 222                  M3M Heights  2.79 Crore  ₹ 14,168/sq.ft.
# 1718       Antriksh Heights3.7 ★      85 Lac   ₹ 4,927/sq.ft.
#
# ...

# %%
df.shape
# Out:
# (3028, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3028 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3028 non-null   str
#  1   link             3028 non-null   str
#  2   society          3027 non-null   str
#  3   price            3008 non-null   str
#  4   area             3015 non-null   str
#  5   areaWithType     3009 non-null   str
#  6   bedRoom          3009 non-null   str
#  7   bathroom         3009 non-null   str
#  8   balcony          3009 non-null   str
#  9   additionalRoom   1695 non-null   str
#  10  address          3003 non-null   str
#  11  floorNum         3007 non-null   str
#  12  facing           2128 non-null   str
#  13  agePossession    3008 non-null   str
#  14  nearbyLocations  2914 non-null   str
#  15  description      3009 non-null   str
#  16  furnishDetails   2204 non-null   str
#  17  features         2595 non-null   str
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# property_name         0
# link                  0
# society               1
# price                20
# area                 13
# areaWithType         19
# bedRoom              19
# bathroom             19
# balcony              19
# additionalRoom     1333
# address              25
# floorNum             21
# facing              900
# agePossession        20
# nearbyLocations     114
# description          19
# furnishDetails      824
# features            433
# rating              351
# property_id          19
# dtype: int64

# %%
df.drop(columns=['link','property_id'],inplace=True)

# %%
df.head(1)
# Out:
#                   property_name                 society   price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency  45 Lac
#
#              area                    areaWithType     bedRoom     bathroom  \
# 0  ₹ 5,000/sq.ft.  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
#
#      balcony additionalRoom                           address  \
# 0  1 Balcony            NaN  Krishna Colony, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
#
# ...

# %%
df.rename(columns={'area':'price_per_sqft'},inplace=True)

# %%
df['society'].value_counts()
# Out:
# society
# SS The Leaf3.8 ★                                     73
# Tulip Violet4.3 ★                                    40
# Shapoorji Pallonji Joyville Gurugram4.0 ★            39
# Signature Global Park4.0 ★                           36
# Shree Vardhman Victoria3.8 ★                         35
# Tulip Violet4.2 ★                                    33
# Smart World Orchard                                  32
# Smart World Gems                                     32
# Emaar MGF Emerald Floors Premier3.8 ★                32
# Paras Dews                                           31
# DLF The Ultima4.0 ★                                  31
# DLF Regal Gardens3.9 ★                               30
# Shree Vardhman Flora3.8 ★                            29
# M3M Woodshire4.0 ★                                   29
# La Vida by Tata Housing                              28
# Signature Global Solera3.7 ★                         28
# Godrej Nature Plus                                   27
# ...

# %%
df['society'].value_counts().shape
# Out:
# (639,)

# %%
import re
df['society']=df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df.head(2)
# Out:
#                   property_name                 society   price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency  45 Lac
# 1     2 BHK Flat in Ashok Vihar            apna enclave  50 Lac
#
#    price_per_sqft                    areaWithType     bedRoom     bathroom  \
# 0  ₹ 5,000/sq.ft.  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# 1  ₹ 7,692/sq.ft.  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
#
#      balcony additionalRoom                             address  \
# 0  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
# ...

# %%
df['society'].value_counts().shape
# Out:
# (605,)

# %%
df['price'].value_counts()
# Out:
# price
# 1.25 Crore          79
# 1.1 Crore           61
# 1.4 Crore           60
# 1.2 Crore           59
# 1.5 Crore           59
# 90 Lac              58
# 1.3 Crore           57
# 95 Lac              53
# 2 Crore             51
# 1.75 Crore          47
# 1 Crore             46
# 1.6 Crore           43
# 1.35 Crore          41
# 1.55 Crore          40
# 1.9 Crore           40
# 75 Lac              38
# 1.65 Crore          38
# 1.8 Crore           37
# 1.7 Crore           37
# 80 Lac              36
# 2.2 Crore           34
# 50 Lac              33
# 1.15 Crore          33
# 85 Lac              31
# 1.45 Crore          31
# 1.05 Crore          30
# 40 Lac              29
# 2.5 Crore           29
# 60 Lac              29
# 45 Lac              26
# 2.1 Crore           26
# 65 Lac              25
# 1.85 Crore          23
# 2.35 Crore          23
# 35 Lac              23
# 3 Crore             22
# 70 Lac              21
# 2.25 Crore          20
# 55 Lac              20
# ...

# %%
df[df['price']=='Price on Request']
# Out:
#                          property_name                    society  \
# 25      5 BHK Flat in Sector 1 Gurgaon  the new people apartments
# 1645   4 BHK Flat in Sector 50 Gurgaon                ss hibiscus
# 1973   1 BHK Flat in Sector 31 Gurgaon            raheja atlantis
# 2055   2 BHK Flat in Sector 79 Gurgaon         supertech araville
# 2358  2 BHK Flat in Sector 37D Gurgaon            the millennia 2
# 2523  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2550      3 BHK Flat in Sector-2 Sohna         supertech hilltown
# 2641  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2960  3 BHK Flat in Sector 104 Gurgaon              godrej summit
# 2973         4 BHK Flat in Gwal Pahari     krrish provence estate
# 2974   4 BHK Flat in Sector 95 Gurgaon    sidhartha ncr one phase
#
#                  price price_per_sqft  \
# 25    Price on Request            NaN
# 1645  Price on Request            NaN
# 1973  Price on Request            NaN
# ...

# %%
df.shape
# Out:
# (3028, 18)

# %%
df=df[df['price'] != 'Price on Request']

# %%
df.shape
# Out:
# (3017, 18)

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            apna enclave      50 Lac
# 2              2 BHK Flat in Sohna  tulsiani easy in homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
def convert_to_crore(value):
    value = str(value).strip().lower()

    if 'crore' in value:
        return float(value.replace('crore', '').strip())

    elif 'lac' in value or 'lakh' in value:
        num = (
            value.replace('lac', '')
                 .replace('lakh', '')
                 .strip()
        )
        return float(num) / 100

    return None  # or float(value) if needed

# %%
# Apply on column
df['price'] = df['price'].apply(convert_to_crore)

# %%
df.sample(5)
# Out:
#                           property_name                      society  price  \
# 528           1 BHK Flat in Palam Vihar  bestech park view residency  0.562
# 1510    3 BHK Flat in Sector 56 Gurgaon      professors enclave cghs  1.540
# 2222    2 BHK Flat in Sector 91 Gurgaon                   tarc maceo  0.950
# 2050  3 BHK Flat in Sector 89 A Gurgaon                 ats marigold  1.850
# 815    3 BHK Flat in Sector 111 Gurgaon       puri diplomatic greens  2.580
#
#        price_per_sqft                                       areaWithType  \
# 528    ₹ 8,632/sq.ft.                     Carpet area: 651 (60.48 sq.m.)
# 1510   ₹ 8,324/sq.ft.  Super Built up area 2000(185.81 sq.m.)Built Up...
# 2222   ₹ 5,954/sq.ft.              Super Built up area 1310(121.7 sq.m.)
# 2050   ₹ 8,604/sq.ft.             Super Built up area 2150(199.74 sq.m.)
# 815   ₹ 11,727/sq.ft.             Super Built up area 2200(204.39 sq.m.)
#
# ...

# %%
df['price_per_sqft']=df['price_per_sqft'].str.split().str[1].str.split('/').str[0].str.replace(",","").astype(float)

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType     bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df['bedRoom'].isnull().sum()
# Out:
# np.int64(19)

# %%
df[df['bedRoom'].isnull()]
# Out:
#                                         property_name  \
# 2850                 2 BHK Flat in Sector 107 Gurgaon
# 2851                  4 BHK Flat in Sector 53 Gurgaon
# 2852                    2 BHK Flat in New Palam Vihar
# 2853                              2 BHK Flat in Sohna
# 2923                 3 BHK Flat in Sector 99A Gurgaon
# 2924               1 BHK Flat in Golf Course Ext Road
# 2925                  2 BHK Flat in Sector 89 Gurgaon
# 2927        4 BHK Flat in C Block Sushant Lok Phase 1
# 2928                  2 BHK Flat in Sector 99 Gurgaon
# 2994                        4 BHK Flat in DLF Phase 4
# 2995                  3 BHK Flat in Sector 9A Gurgaon
# 2996                 3 BHK Flat in Sector 37C Gurgaon
# 2997                       3 BHK Flat in Adarsh Nagar
# 2998                      3 BHK Flat in Rajendra Park
# 2999                  2 BHK Flat in Sector 79 Gurgaon
# 3000                 3 BHK Flat in Sector 37C Gurgaon
# ...

# %%
df=df[~df['bedRoom'].isnull()]

# %%
df.sample(5)
# Out:
#                          property_name                     society  price  \
# 945     1 BHK Flat in Sector 2 Gurgaon  ansal api celebrity suites   0.60
# 2030   3 BHK Flat in Sector 81 Gurgaon    bestech park view ananda   1.35
# 1099  2 BHK Flat in Sector 107 Gurgaon               m3m woodshire   0.88
# 963   3 BHK Flat in Sector 108 Gurgaon                  sobha city   2.45
# 2343  2 BHK Flat in Sector 95A Gurgaon               the roselia 2   0.45
#
#       price_per_sqft                                       areaWithType  \
# 945           8163.0               Super Built up area 735(68.28 sq.m.)
# 2030          7541.0                    Carpet area: 1790 (166.3 sq.m.)
# 1099          6442.0             Super Built up area 1366(126.91 sq.m.)
# 963          14040.0  Super Built up area 1745(162.12 sq.m.)Built Up...
# 2343          6475.0  Built Up area: 695 (64.57 sq.m.)Carpet area: 5...
#
#          bedRoom     bathroom       balcony additionalRoom  \
# ...

# %%
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 3 Bedrooms    1437
# 2 Bedrooms     944
# 4 Bedrooms     478
# 1 Bedroom      104
# 5 Bedrooms      31
# 6 Bedrooms       3
# bedRoom          1
# Name: count, dtype: int64

# %%
df[df['bedRoom']=='bedRoom']
# Out:
#      property_name  society  price  price_per_sqft  areaWithType  bedRoom  \
# 286  property_name  society    NaN             NaN  areaWithType  bedRoom
#
#      bathroom  balcony  additionalRoom  address  floorNum  facing  \
# 286  bathroom  balcony  additionalRoom  address  floorNum  facing
#
#      agePossession  nearbyLocations  description  furnishDetails  features  \
# 286  agePossession  nearbyLocations  description  furnishDetails  features
#
#      rating
# 286  rating

# %%
df.drop(df.index[df['bedRoom'] == 'bedRoom'], inplace=True)

# %%
df['bedRoom']=df['bedRoom'].str.split(' ').str[0].astype(int)

# %%
df['bathroom'].value_counts()
# Out:
# bathroom
# 2 Bathrooms    1044
# 3 Bathrooms     989
# 4 Bathrooms     636
# 5 Bathrooms     169
# 1 Bathroom      112
# 6 Bathrooms      42
# 7 Bathrooms       5
# Name: count, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3 Balconies     974
# 3+ Balconies    862
# 2 Balconies     749
# 1 Balcony       315
# No Balcony       97
# Name: count, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
def balcony_to_int(value):
    if pd.isnull(value):
        return 0
    else:
        if value=='No Balcony':
            return 0
        return int(value.split()[0])

# %%
df['balcony']=df['balcony'].str.split().str[0].str.replace('No','0')

# %%
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# Servant Room                                     629
# Study Room                                       232
# Others                                           179
# Pooja Room                                       132
# Study Room,Servant Room                           81
# Store Room                                        76
# Pooja Room,Servant Room                           60
# Servant Room,Others                               52
# Servant Room,Pooja Room                           30
# Study Room,Others                                 27
# Pooja Room,Study Room,Servant Room,Others         25
# Pooja Room,Study Room,Servant Room                24
# Servant Room,Store Room                           19
# Pooja Room,Study Room                             13
# Pooja Room,Study Room,Servant Room,Store Room     12
# Servant Room,Study Room                            8
# Study Room,Pooja Room                              8
# ...

# %%
df['additionalRoom'].isnull().sum()
# Out:
# np.int64(1305)

# %%
df['additionalRoom']=df['additionalRoom'].fillna('not available',inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_26668\941797568.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['additionalRoom']=df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom']=df['additionalRoom'].str.lower()

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
df['floorNum'].value_counts()
# Out:
# floorNum
# 2nd   of 4 Floors           74
# 3rd   of 4 Floors           71
# 4th   of 4 Floors           62
# 1st   of 4 Floors           61
# 12nd   of 14 Floors         49
# 14th   of 14 Floors         48
# Ground of 14 Floors         40
# 10th   of 14 Floors         35
# 7th   of 14 Floors          35
# 8th   of 14 Floors          34
# 4th   of 14 Floors          28
# 6th   of 14 Floors          27
# 3rd   of 3 Floors           26
# 2nd   of 2 Floors           26
# 1st   of 14 Floors          26
# 3rd   of 14 Floors          24
# 8th   of 19 Floors          24
# 5th   of 14 Floors          24
# 11st   of 14 Floors         23
# 1st   of 1 Floors           23
# 9th   of 9 Floors           23
# 9th   of 14 Floors          23
# 2nd   of 3 Floors           22
# 5th   of 12 Floors          22
# 2nd   of 14 Floors          21
# 8th   of 18 Floors          20
# 6th   of 18 Floors          18
# 10th   of 19 Floors         18
# Ground of 1 Floors          17
# ...

# %%
df['floorNum']=df['floorNum'].str.split().str[0].str.replace('Ground','0').str.replace('Basement','-1').str.replace('Lower','0').str.extract(r'(\d+)')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address floorNum facing  \
# ...

# %%
df['facing'].value_counts()
# Out:
# facing
# North-East    505
# East          490
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(874)

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_26668\3133442517.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['facing'].fillna('N',inplace=True)
# 0             West
# 1             West
# 2                N
# 3                N
# 4                N
# 5                N
# 6                N
# 7                N
# ...

# %%
df['facing'].value_counts()
# Out:
# facing
# North-East    505
# East          490
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(874)

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address floorNum facing  \
# ...

# %%
df.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
df.insert(loc=1,column='property_type',value='flat')

# %%
df.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   0.45          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2997 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2997 non-null   str
#  1   property_type    2997 non-null   str
#  2   society          2997 non-null   str
#  3   price            2996 non-null   float64
#  4   price_per_sqft   2996 non-null   float64
#  5   area             2996 non-null   float64
#  6   areaWithType     2997 non-null   str
#  7   bedRoom          2997 non-null   int64
#  8   bathroom         2997 non-null   int64
#  9   balcony          2997 non-null   object
#  10  additionalRoom   2997 non-null   str
#  11  address          2991 non-null   str
#  12  floorNum         2995 non-null   object
#  13  facing           2123 non-null   str
#  14  agePossession    2996 non-null   str
#  15  nearbyLocations  2906 non-null   str
#  16  description      2997 non-null   str
# ...

# %%
df.to_csv('flats_cleaned.csv',index=False)
